# %% [markdown]
# <h1>작업형 문제1 답안</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    if name in row[0]:
        home = np.array(row[3:], dtype=int)

f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home)
plt.title(name + ' 지역의 인구 구조')
plt.xlabel('나이')
plt.ylabel('인구수')
plt.grid(True)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 신도림

# %% [markdown]
# <h1>여기서 잠깐!</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

print(type(data))
data = list(data)
print(type(data))

# 자료형을 list로 변환해야, 작업형 문제5에서 for 반복문을 연속해서 사용하는 것이 가능합니다.
# Out:
# <class '_csv.reader'>
# <class 'list'>

# %% [markdown]
# <h1>작업형 문제2 답안</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

data = list(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    for i in range(102):
        row[i + 2] = int(row[i + 2].replace(',', ''))
    if name in row[0]:
        home = np.array(row[3:], dtype=int) / row[2]

f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home)
plt.title(name + ' 지역의 인구 구조')
plt.xlabel('나이')
plt.ylabel('인구 비율')
plt.grid(True)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 신도림

# %% [markdown]
# <h1>작업형 문제3 답안</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

data = list(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    for i in range(102):
        row[i + 2] = int(row[i + 2].replace(',', ''))
    if name in row[0]:
        home = np.array(row[3:], dtype=int) / row[2]
    if '화촌면' in row[0]:
        away = np.array(row[3:], dtype=int) / row[2]

f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home, label=name)
plt.plot(away, label='화촌면')
plt.title(name + ' 지역과 화촌면 지역의 인구 구조 비교')
plt.xlabel('나이')
plt.ylabel('인구 비율')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 신도림

# %% [markdown]
# <h1>작업형 문제4 답안</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

data = list(data)

min_val = 1        # 최소값을 저장할 변수 생성 및 초기화
result_name = ''   # 최소값을 갖는 지역의 이름을 저장할 변수 생성 및 초기화
result = 0         # 최소값을 갖는 치역의 연령대별 인구 비율을 저장할 배열 생성 및 초기화

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    for i in range(102):
        row[i + 2] = int(row[i + 2].replace(',', ''))
    if name in row[0]:
        home = np.array(row[3:], dtype=int) / row[2]

for row in data:
    if (name not in row[0]) and (row[2] != 0):
        away = np.array(row[3:]) / row[2]
        s = np.sum(home - away)
        if s < min_val:
            min_val = s
            result_name = row[0]
            result = away

f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home, label=name)
plt.plot(result, label=result_name)
plt.title(name + ' 지역과 ' + result_name + ' 지역의 인구 구조 비교')
plt.xlabel('나이')
plt.ylabel('인구 비율')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 신도림

# %% [markdown]
# <h1>작업형 문제5 답안</h1>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age_0922.csv')
data = csv.reader(f)

header = next(data)

data = list(data)

min_val = 1        # 최소값을 저장할 변수 생성 및 초기화
result_name = ''   # 최소값을 갖는 지역의 이름을 저장할 변수 생성 및 초기화
result = 0         # 최소값을 갖는 치역의 연령대별 인구 비율을 저장할 배열 생성 및 초기화

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    for i in range(102):
        row[i + 2] = int(row[i + 2].replace(',', ''))
    if name in row[0]:
        home = np.array(row[3:], dtype=int) / row[2]

for row in data:
    if (name not in row[0]) and (row[2] != 0):
        away = np.array(row[3:]) / row[2]
        s = np.sum((home - away)**2)
        if s < min_val:
            min_val = s
            result_name = row[0]
            result = away

f.close()

plt.rc('font', family='Malgun Gothic')
plt.plot(home, label=name)
plt.plot(result, label=result_name)
plt.title(name + ' 지역과 ' + result_name + ' 지역의 인구 구조 비교')
plt.xlabel('나이')
plt.ylabel('인구 비율')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: 신도림
